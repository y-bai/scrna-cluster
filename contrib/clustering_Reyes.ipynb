# %%
import os
import numpy as np
import pandas as pd
import random
import time
import scanpy as sc
import torch

import warnings
warnings.filterwarnings('ignore')
import logging
logging.basicConfig(level=logging.INFO)
import scDualGN

def seed_torch(seed=666):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.enabled = False
seed_torch()

# %%
#load data
adata = sc.read_h5ad('/media/bgi/zhouruilong/paper_test/cluster/our_model/Patient_PBMCs/scp_scanpy.h5ad')
adata.obs['celltype'] = adata.obs['cell_type']
adata.obs['celltype_str'] = adata.obs['cell_type']
                                
arr = np.array(adata.obs['celltype'])
np.place(arr,arr=='T',[0])
np.place(arr,arr=='B',[1])
np.place(arr,arr=='NK',[2])
np.place(arr,arr=='Mono',[3])
np.place(arr,arr=='DC',[4])


arr = arr.astype(np.int32)
adata.obs['celltype'] = arr

# %%
sc.pp.filter_cells(adata, min_counts=200)
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.normalize_total(adata,target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=2500)
adata = adata[:, adata.var.highly_variable]
    #adata.X = minmax_scale(adata.X, feature_range=(0, 1), axis=1, copy=False)
sc.pp.scale(adata,max_value=10)

# %%
#kmeans
start = time.time()
z_final, y_pred_lab, model = scDualGN.run_scDualGN(adata, n_cluster=5,n_z=32,n_epoch_update_pq=5, n_epochs=30,alpha_dualvae=0.025,beta_daulvae=20,gamma_dualvae=2,GPU_id=1)
end = time.time()

print('running time = {}'.format(end-start))
# Out:
# INFO:scDualGN.run:device: cuda:1
# INFO:scDualGN.run:pretrain device: cuda:1
# INFO:scDualGN.run:start pretraining...
# INFO:scDualGN.run:Epoch 0/50,Overall loss:15001.8027,MSE:727.1671,MSE1:228.9205,KL: 24.7618
# INFO:scDualGN.run:Epoch 1/50,Overall loss:10991.0715,MSE:546.8658,MSE1:26.1522,KL: 58.0584
# INFO:scDualGN.run:Epoch 2/50,Overall loss:10605.2067,MSE:529.2635,MSE1:9.0019,KL: 77.3024
# INFO:scDualGN.run:Epoch 3/50,Overall loss:10475.8142,MSE:523.0767,MSE1:6.0657,KL: 85.9542
# INFO:scDualGN.run:Epoch 4/50,Overall loss:10375.3375,MSE:518.1557,MSE1:4.9840,KL: 90.1981
# INFO:scDualGN.run:Epoch 5/50,Overall loss:10296.5678,MSE:514.2815,MSE1:4.2905,KL: 94.3113
# INFO:scDualGN.run:Epoch 6/50,Overall loss:10241.3780,MSE:511.5771,MSE1:3.6820,KL: 98.8817
# INFO:scDualGN.run:Epoch 7/50,Overall loss:10198.6434,MSE:509.4809,MSE1:3.2345,KL: 102.2671
# INFO:scDualGN.run:Epoch 8/50,Overall loss:10157.3681,MSE:507.4387,MSE1:2.9991,KL: 103.8146
# INFO:scDualGN.run:Epoch 9/50,Overall loss:10115.7431,MSE:505.3712,MSE1:2.8502,KL: 104.7773
# INFO:scDualGN.run:Epoch 10/50,Overall loss:10078.3882,MSE:503.5172,MSE1:2.6955,KL: 106.1522
# INFO:scDualGN.run:Epoch 11/50,Overall loss:10043.8107,MSE:501.8007,MSE1:2.5627,KL: 106.8682
# INFO:scDualGN.run:Epoch 12/50,Overall loss:10011.0280,MSE:500.1727,MSE1:2.4530,KL: 106.6932
# INFO:scDualGN.run:Epoch 13/50,Overall loss:9979.8096,MSE:498.6200,MSE1:2.3779,KL: 106.1849
# INFO:scDualGN.run:Epoch 14/50,Overall loss:9948.1543,MSE:497.0426,MSE1:2.3301,KL: 105.6743
# INFO:scDualGN.run:Epoch 15/50,Overall loss:9915.6418,MSE:495.4195,MSE1:2.3133,KL: 104.9853
# INFO:scDualGN.run:Epoch 16/50,Overall loss:9879.9822,MSE:493.6379,MSE1:2.3017,KL: 104.8222
# INFO:scDualGN.run:Epoch 17/50,Overall loss:9842.5052,MSE:491.7645,MSE1:2.2912,KL: 105.2797
# INFO:scDualGN.run:Epoch 18/50,Overall loss:9802.8760,MSE:489.7844,MSE1:2.2625,KL: 106.5463
# INFO:scDualGN.run:Epoch 19/50,Overall loss:9761.4798,MSE:487.7159,MSE1:2.2205,KL: 108.7934
# INFO:scDualGN.run:Epoch 20/50,Overall loss:9720.2757,MSE:485.6607,MSE1:2.1333,KL: 111.8160
# INFO:scDualGN.run:Epoch 21/50,Overall loss:9679.2316,MSE:483.6134,MSE1:2.0390,KL: 115.4057
# INFO:scDualGN.run:Epoch 22/50,Overall loss:9639.5159,MSE:481.6343,MSE1:1.9224,KL: 119.4089
# INFO:scDualGN.run:Epoch 23/50,Overall loss:9601.2629,MSE:479.7284,MSE1:1.8020,KL: 123.6634
# INFO:scDualGN.run:Epoch 24/50,Overall loss:9562.9557,MSE:477.8192,MSE1:1.6842,KL: 128.1342
# INFO:scDualGN.run:Epoch 25/50,Overall loss:9526.5607,MSE:476.0058,MSE1:1.5615,KL: 132.8906
# INFO:scDualGN.run:Epoch 26/50,Overall loss:9491.7241,MSE:474.2703,MSE1:1.4371,KL: 137.7404
# INFO:scDualGN.run:Epoch 27/50,Overall loss:9459.1818,MSE:472.6491,MSE1:1.3155,KL: 142.7566
# INFO:scDualGN.run:Epoch 28/50,Overall loss:9427.1903,MSE:471.0538,MSE1:1.2114,KL: 147.7046
# INFO:scDualGN.run:Epoch 29/50,Overall loss:9397.3632,MSE:469.5668,MSE1:1.1066,KL: 152.5920
# INFO:scDualGN.run:Epoch 30/50,Overall loss:9368.6298,MSE:468.1329,MSE1:1.0187,KL: 157.3641
# INFO:scDualGN.run:Epoch 31/50,Overall loss:9340.6089,MSE:466.7345,MSE1:0.9324,KL: 162.1655
# INFO:scDualGN.run:Epoch 32/50,Overall loss:9314.9549,MSE:465.4533,MSE1:0.8581,KL: 166.9114
# INFO:scDualGN.run:Epoch 33/50,Overall loss:9289.0681,MSE:464.1601,MSE1:0.7900,KL: 171.4707
# INFO:scDualGN.run:Epoch 34/50,Overall loss:9265.7266,MSE:462.9937,MSE1:0.7266,KL: 175.9668
# INFO:scDualGN.run:Epoch 35/50,Overall loss:9242.8130,MSE:461.8481,MSE1:0.6713,KL: 180.3585
# INFO:scDualGN.run:Epoch 36/50,Overall loss:9221.8449,MSE:460.7994,MSE1:0.6222,KL: 184.5022
# INFO:scDualGN.run:Epoch 37/50,Overall loss:9200.5232,MSE:459.7325,MSE1:0.5793,KL: 188.6046
# INFO:scDualGN.run:Epoch 38/50,Overall loss:9181.2929,MSE:458.7704,MSE1:0.5354,KL: 192.5423
# INFO:scDualGN.run:Epoch 39/50,Overall loss:9161.8399,MSE:457.7966,MSE1:0.5003,KL: 196.2706
# INFO:scDualGN.run:Epoch 40/50,Overall loss:9143.0622,MSE:456.8565,MSE1:0.4677,KL: 199.8353
# INFO:scDualGN.run:Epoch 41/50,Overall loss:9125.8795,MSE:455.9961,MSE1:0.4377,KL: 203.3094
# INFO:scDualGN.run:Epoch 42/50,Overall loss:9107.9047,MSE:455.0958,MSE1:0.4113,KL: 206.6583
# INFO:scDualGN.run:Epoch 43/50,Overall loss:9090.8297,MSE:454.2406,MSE1:0.3859,KL: 209.7978
# INFO:scDualGN.run:Epoch 44/50,Overall loss:9074.6419,MSE:453.4296,MSE1:0.3642,KL: 212.8605
# INFO:scDualGN.run:Epoch 45/50,Overall loss:9059.0026,MSE:452.6459,MSE1:0.3441,KL: 215.8263
# INFO:scDualGN.run:Epoch 46/50,Overall loss:9044.1053,MSE:451.8995,MSE1:0.3247,KL: 218.6108
# INFO:scDualGN.run:Epoch 47/50,Overall loss:9028.5566,MSE:451.1203,MSE1:0.3081,KL: 221.3553
# INFO:scDualGN.run:Epoch 48/50,Overall loss:9014.4020,MSE:450.4109,MSE1:0.2925,KL: 223.9810
# INFO:scDualGN.run:Epoch 49/50,Overall loss:8998.9886,MSE:449.6386,MSE1:0.2778,KL: 226.4304
# INFO:scDualGN.run:dual-VAE pretrain finished!
# INFO:scDualGN.run:obtain daul-VAE z-vector and x_bar
# INFO:scDualGN.run:perform kmeans to cluster....
# INFO:scDualGN.run:training scDualGN...
# INFO:scDualGN.run:epoch 1/30
# INFO:scDualGN.evalution:acc=0.8911, nmi=0.8073, ari=0.8472
# INFO:scDualGN.run:Epoch 1/30, Loss - overall: 8988.9038,daul_VAE:8988.8686,KL:0.0254,Center:101.9047
# INFO:scDualGN.run:Epoch 2/30, Loss - overall: 8974.4783,daul_VAE:8974.4431,KL:0.0252,Center:101.7385
# INFO:scDualGN.run:Epoch 3/30, Loss - overall: 8966.9749,daul_VAE:8966.9404,KL:0.0249,Center:101.4955
# INFO:scDualGN.run:Epoch 4/30, Loss - overall: 8963.7495,daul_VAE:8963.7154,KL:0.0246,Center:101.2815
# INFO:scDualGN.run:Epoch 5/30, Loss - overall: 8955.2452,daul_VAE:8955.2111,KL:0.0244,Center:101.0690
# INFO:scDualGN.run:epoch 6/30
# INFO:scDualGN.evalution:acc=0.8890, nmi=0.8069, ari=0.8462
# INFO:scDualGN.run:Epoch 6/30, Loss - overall: 8949.7274,daul_VAE:8949.6914,KL:0.0262,Center:100.8926
# INFO:scDualGN.run:Epoch 7/30, Loss - overall: 8943.5619,daul_VAE:8943.5264,KL:0.0258,Center:100.6525
# INFO:scDualGN.run:Epoch 8/30, Loss - overall: 8939.2956,daul_VAE:8939.2604,KL:0.0256,Center:100.3505
# INFO:scDualGN.run:Epoch 9/30, Loss - overall: 8931.4245,daul_VAE:8931.3894,KL:0.0253,Center:100.0155
# INFO:scDualGN.run:Epoch 10/30, Loss - overall: 8924.3243,daul_VAE:8924.2893,KL:0.0250,Center:99.8213
# INFO:scDualGN.run:epoch 11/30
# INFO:scDualGN.evalution:acc=0.8903, nmi=0.8051, ari=0.8466
# INFO:scDualGN.run:Epoch 11/30, Loss - overall: 8921.0418,daul_VAE:8921.0056,KL:0.0265,Center:99.2946
# INFO:scDualGN.run:Epoch 12/30, Loss - overall: 8914.0313,daul_VAE:8913.9953,KL:0.0261,Center:99.1058
# INFO:scDualGN.run:Epoch 13/30, Loss - overall: 8907.3977,daul_VAE:8907.3620,KL:0.0259,Center:98.6724
# INFO:scDualGN.run:Epoch 14/30, Loss - overall: 8903.1576,daul_VAE:8903.1224,KL:0.0256,Center:98.3258
# INFO:scDualGN.run:Epoch 15/30, Loss - overall: 8897.7976,daul_VAE:8897.7624,KL:0.0254,Center:97.9663
# INFO:scDualGN.run:epoch 16/30
# INFO:scDualGN.evalution:acc=0.8951, nmi=0.8055, ari=0.8497
# INFO:scDualGN.run:Epoch 16/30, Loss - overall: 8892.5680,daul_VAE:8892.5316,KL:0.0267,Center:97.4656
# INFO:scDualGN.run:Epoch 17/30, Loss - overall: 8889.1988,daul_VAE:8889.1627,KL:0.0264,Center:97.0753
# INFO:scDualGN.run:Epoch 18/30, Loss - overall: 8880.9337,daul_VAE:8880.8977,KL:0.0262,Center:96.7032
# INFO:scDualGN.run:Epoch 19/30, Loss - overall: 8878.5373,daul_VAE:8878.5015,KL:0.0260,Center:96.3200
# INFO:scDualGN.run:Epoch 20/30, Loss - overall: 8870.7602,daul_VAE:8870.7249,KL:0.0257,Center:95.9047
# INFO:scDualGN.run:epoch 21/30
# INFO:scDualGN.evalution:acc=0.8979, nmi=0.8036, ari=0.8509
# INFO:scDualGN.run:Epoch 21/30, Loss - overall: 8866.5898,daul_VAE:8866.5529,KL:0.0270,Center:95.3625
# INFO:scDualGN.run:Epoch 22/30, Loss - overall: 8863.5747,daul_VAE:8863.5384,KL:0.0268,Center:95.0036
# INFO:scDualGN.run:Epoch 23/30, Loss - overall: 8860.0874,daul_VAE:8860.0512,KL:0.0266,Center:94.5272
# INFO:scDualGN.run:Epoch 24/30, Loss - overall: 8850.6825,daul_VAE:8850.6464,KL:0.0264,Center:94.1712
# INFO:scDualGN.run:Epoch 25/30, Loss - overall: 8846.4311,daul_VAE:8846.3950,KL:0.0262,Center:93.7181
# INFO:scDualGN.run:epoch 26/30
# INFO:scDualGN.evalution:acc=0.8979, nmi=0.8009, ari=0.8493
# INFO:scDualGN.run:Epoch 26/30, Loss - overall: 8843.6850,daul_VAE:8843.6479,KL:0.0273,Center:93.3092
# INFO:scDualGN.run:Epoch 27/30, Loss - overall: 8837.3639,daul_VAE:8837.3271,KL:0.0271,Center:92.9012
# INFO:scDualGN.run:Epoch 28/30, Loss - overall: 8832.1939,daul_VAE:8832.1581,KL:0.0269,Center:92.4464
# INFO:scDualGN.run:Epoch 29/30, Loss - overall: 8828.0156,daul_VAE:8827.9804,KL:0.0267,Center:92.0811
# INFO:scDualGN.run:Epoch 30/30, Loss - overall: 8824.2541,daul_VAE:8824.2188,KL:0.0266,Center:91.7241
# INFO:scDualGN.run:scDualGN train finished.
# INFO:scDualGN.evalution:acc=0.9019, nmi=0.7987, ari=0.8511
# running time = 331.5812213420868

# %%
#leiden
start = time.time()
z_final, y_pred_lab, model = scDualGN.run_scDualGN(adata,n_z=32,n_epoch_update_pq=5, n_epochs=30,alpha_dualvae=0.025,beta_daulvae=20,gamma_dualvae=2,GPU_id=1,
                                                   cluster_alg='leiden',n_neighbors=50)
end = time.time()

print('running time = {}'.format(end-start))
# Out:
# INFO:scDualGN.run:device: cuda:1
# INFO:scDualGN.run:pretrain device: cuda:1
# INFO:scDualGN.run:start pretraining...
# INFO:scDualGN.run:Epoch 0/50,Overall loss:15001.8027,MSE:727.1671,MSE1:228.9205,KL: 24.7618
# INFO:scDualGN.run:Epoch 1/50,Overall loss:10991.0715,MSE:546.8658,MSE1:26.1522,KL: 58.0584
# INFO:scDualGN.run:Epoch 2/50,Overall loss:10605.2067,MSE:529.2635,MSE1:9.0019,KL: 77.3024
# INFO:scDualGN.run:Epoch 3/50,Overall loss:10475.8142,MSE:523.0767,MSE1:6.0657,KL: 85.9542
# INFO:scDualGN.run:Epoch 4/50,Overall loss:10375.3375,MSE:518.1557,MSE1:4.9840,KL: 90.1981
# INFO:scDualGN.run:Epoch 5/50,Overall loss:10296.5678,MSE:514.2815,MSE1:4.2905,KL: 94.3113
# INFO:scDualGN.run:Epoch 6/50,Overall loss:10241.3780,MSE:511.5771,MSE1:3.6820,KL: 98.8817
# INFO:scDualGN.run:Epoch 7/50,Overall loss:10198.6434,MSE:509.4809,MSE1:3.2345,KL: 102.2671
# INFO:scDualGN.run:Epoch 8/50,Overall loss:10157.3681,MSE:507.4387,MSE1:2.9991,KL: 103.8146
# INFO:scDualGN.run:Epoch 9/50,Overall loss:10115.7431,MSE:505.3712,MSE1:2.8502,KL: 104.7773
# INFO:scDualGN.run:Epoch 10/50,Overall loss:10078.3882,MSE:503.5172,MSE1:2.6955,KL: 106.1522
# INFO:scDualGN.run:Epoch 11/50,Overall loss:10043.8107,MSE:501.8007,MSE1:2.5627,KL: 106.8682
# INFO:scDualGN.run:Epoch 12/50,Overall loss:10011.0280,MSE:500.1727,MSE1:2.4530,KL: 106.6932
# INFO:scDualGN.run:Epoch 13/50,Overall loss:9979.8096,MSE:498.6200,MSE1:2.3779,KL: 106.1849
# INFO:scDualGN.run:Epoch 14/50,Overall loss:9948.1543,MSE:497.0426,MSE1:2.3301,KL: 105.6743
# INFO:scDualGN.run:Epoch 15/50,Overall loss:9915.6418,MSE:495.4195,MSE1:2.3133,KL: 104.9853
# INFO:scDualGN.run:Epoch 16/50,Overall loss:9879.9822,MSE:493.6379,MSE1:2.3017,KL: 104.8222
# INFO:scDualGN.run:Epoch 17/50,Overall loss:9842.5052,MSE:491.7645,MSE1:2.2912,KL: 105.2797
# INFO:scDualGN.run:Epoch 18/50,Overall loss:9802.8760,MSE:489.7844,MSE1:2.2625,KL: 106.5463
# INFO:scDualGN.run:Epoch 19/50,Overall loss:9761.4798,MSE:487.7159,MSE1:2.2205,KL: 108.7934
# INFO:scDualGN.run:Epoch 20/50,Overall loss:9720.2757,MSE:485.6607,MSE1:2.1333,KL: 111.8160
# INFO:scDualGN.run:Epoch 21/50,Overall loss:9679.2316,MSE:483.6134,MSE1:2.0390,KL: 115.4057
# INFO:scDualGN.run:Epoch 22/50,Overall loss:9639.5159,MSE:481.6343,MSE1:1.9224,KL: 119.4089
# INFO:scDualGN.run:Epoch 23/50,Overall loss:9601.2629,MSE:479.7284,MSE1:1.8020,KL: 123.6634
# INFO:scDualGN.run:Epoch 24/50,Overall loss:9562.9557,MSE:477.8192,MSE1:1.6842,KL: 128.1342
# INFO:scDualGN.run:Epoch 25/50,Overall loss:9526.5607,MSE:476.0058,MSE1:1.5615,KL: 132.8906
# INFO:scDualGN.run:Epoch 26/50,Overall loss:9491.7241,MSE:474.2703,MSE1:1.4371,KL: 137.7404
# INFO:scDualGN.run:Epoch 27/50,Overall loss:9459.1818,MSE:472.6491,MSE1:1.3155,KL: 142.7566
# INFO:scDualGN.run:Epoch 28/50,Overall loss:9427.1903,MSE:471.0538,MSE1:1.2114,KL: 147.7046
# INFO:scDualGN.run:Epoch 29/50,Overall loss:9397.3632,MSE:469.5668,MSE1:1.1066,KL: 152.5920
# INFO:scDualGN.run:Epoch 30/50,Overall loss:9368.6298,MSE:468.1329,MSE1:1.0187,KL: 157.3641
# INFO:scDualGN.run:Epoch 31/50,Overall loss:9340.6089,MSE:466.7345,MSE1:0.9324,KL: 162.1655
# INFO:scDualGN.run:Epoch 32/50,Overall loss:9314.9549,MSE:465.4533,MSE1:0.8581,KL: 166.9114
# INFO:scDualGN.run:Epoch 33/50,Overall loss:9289.0681,MSE:464.1601,MSE1:0.7900,KL: 171.4707
# INFO:scDualGN.run:Epoch 34/50,Overall loss:9265.7266,MSE:462.9937,MSE1:0.7266,KL: 175.9668
# INFO:scDualGN.run:Epoch 35/50,Overall loss:9242.8130,MSE:461.8481,MSE1:0.6713,KL: 180.3585
# INFO:scDualGN.run:Epoch 36/50,Overall loss:9221.8449,MSE:460.7994,MSE1:0.6222,KL: 184.5022
# INFO:scDualGN.run:Epoch 37/50,Overall loss:9200.5232,MSE:459.7325,MSE1:0.5793,KL: 188.6046
# INFO:scDualGN.run:Epoch 38/50,Overall loss:9181.2929,MSE:458.7704,MSE1:0.5354,KL: 192.5423
# INFO:scDualGN.run:Epoch 39/50,Overall loss:9161.8399,MSE:457.7966,MSE1:0.5003,KL: 196.2706
# INFO:scDualGN.run:Epoch 40/50,Overall loss:9143.0622,MSE:456.8565,MSE1:0.4677,KL: 199.8353
# INFO:scDualGN.run:Epoch 41/50,Overall loss:9125.8795,MSE:455.9961,MSE1:0.4377,KL: 203.3094
# INFO:scDualGN.run:Epoch 42/50,Overall loss:9107.9047,MSE:455.0958,MSE1:0.4113,KL: 206.6583
# INFO:scDualGN.run:Epoch 43/50,Overall loss:9090.8297,MSE:454.2406,MSE1:0.3859,KL: 209.7978
# INFO:scDualGN.run:Epoch 44/50,Overall loss:9074.6419,MSE:453.4296,MSE1:0.3642,KL: 212.8605
# INFO:scDualGN.run:Epoch 45/50,Overall loss:9059.0026,MSE:452.6459,MSE1:0.3441,KL: 215.8263
# INFO:scDualGN.run:Epoch 46/50,Overall loss:9044.1053,MSE:451.8995,MSE1:0.3247,KL: 218.6108
# INFO:scDualGN.run:Epoch 47/50,Overall loss:9028.5566,MSE:451.1203,MSE1:0.3081,KL: 221.3553
# INFO:scDualGN.run:Epoch 48/50,Overall loss:9014.4020,MSE:450.4109,MSE1:0.2925,KL: 223.9810
# INFO:scDualGN.run:Epoch 49/50,Overall loss:8998.9886,MSE:449.6386,MSE1:0.2778,KL: 226.4304
# INFO:scDualGN.run:dual-VAE pretrain finished!
# INFO:scDualGN.run:obtain daul-VAE z-vector and x_bar
# INFO:scDualGN.run:perform leiden to cluster....
# INFO:scDualGN.run:training scDualGN...
# INFO:scDualGN.run:epoch 1/30
# INFO:scDualGN.evalution:acc=0.7850, nmi=0.6937, ari=3.9114
# INFO:scDualGN.run:Epoch 1/30, Loss - overall: 8985.2912,daul_VAE:8985.2658,KL:0.0154,Center:101.5777
# INFO:scDualGN.run:Epoch 2/30, Loss - overall: 8975.6733,daul_VAE:8975.6480,KL:0.0153,Center:101.4282
# INFO:scDualGN.run:Epoch 3/30, Loss - overall: 8967.1314,daul_VAE:8967.1063,KL:0.0152,Center:101.2432
# INFO:scDualGN.run:Epoch 4/30, Loss - overall: 8959.7576,daul_VAE:8959.7329,KL:0.0151,Center:100.9988
# INFO:scDualGN.run:Epoch 5/30, Loss - overall: 8955.3968,daul_VAE:8955.3724,KL:0.0149,Center:100.8200
# INFO:scDualGN.run:epoch 6/30
# INFO:scDualGN.evalution:acc=0.7853, nmi=0.6939, ari=3.8431
# INFO:scDualGN.run:Epoch 6/30, Loss - overall: 8951.1350,daul_VAE:8951.1096,KL:0.0159,Center:100.4431
# INFO:scDualGN.run:Epoch 7/30, Loss - overall: 8942.5491,daul_VAE:8942.5237,KL:0.0158,Center:100.1574
# INFO:scDualGN.run:Epoch 8/30, Loss - overall: 8937.3843,daul_VAE:8937.3589,KL:0.0157,Center:99.9004
# INFO:scDualGN.run:Epoch 9/30, Loss - overall: 8933.3758,daul_VAE:8933.3504,KL:0.0155,Center:99.5839
# INFO:scDualGN.run:Epoch 10/30, Loss - overall: 8925.0376,daul_VAE:8925.0122,KL:0.0154,Center:99.2139
# INFO:scDualGN.run:epoch 11/30
# INFO:scDualGN.evalution:acc=0.7864, nmi=0.6931, ari=3.9362
# INFO:scDualGN.run:Epoch 11/30, Loss - overall: 8918.1250,daul_VAE:8918.0992,KL:0.0161,Center:98.9293
# INFO:scDualGN.run:Epoch 12/30, Loss - overall: 8914.4236,daul_VAE:8914.3982,KL:0.0160,Center:98.5429
# INFO:scDualGN.run:Epoch 13/30, Loss - overall: 8909.4006,daul_VAE:8909.3752,KL:0.0159,Center:98.1520
# INFO:scDualGN.run:Epoch 14/30, Loss - overall: 8905.3580,daul_VAE:8905.3326,KL:0.0158,Center:97.8029
# INFO:scDualGN.run:Epoch 15/30, Loss - overall: 8898.0314,daul_VAE:8898.0060,KL:0.0157,Center:97.3806
# INFO:scDualGN.run:epoch 16/30
# INFO:scDualGN.evalution:acc=0.7880, nmi=0.6921, ari=4.0319
# INFO:scDualGN.run:Epoch 16/30, Loss - overall: 8892.5028,daul_VAE:8892.4765,KL:0.0164,Center:97.0166
# INFO:scDualGN.run:Epoch 17/30, Loss - overall: 8887.6449,daul_VAE:8887.6186,KL:0.0163,Center:96.6524
# INFO:scDualGN.run:Epoch 18/30, Loss - overall: 8883.1220,daul_VAE:8883.0960,KL:0.0161,Center:96.2008
# INFO:scDualGN.run:Epoch 19/30, Loss - overall: 8877.5911,daul_VAE:8877.5654,KL:0.0161,Center:95.8074
# INFO:scDualGN.run:Epoch 20/30, Loss - overall: 8871.2766,daul_VAE:8871.2510,KL:0.0160,Center:95.3633
# INFO:scDualGN.run:epoch 21/30
# INFO:scDualGN.evalution:acc=0.7890, nmi=0.6913, ari=4.1118
# INFO:scDualGN.run:Epoch 21/30, Loss - overall: 8867.1770,daul_VAE:8867.1507,KL:0.0167,Center:95.0094
# INFO:scDualGN.run:Epoch 22/30, Loss - overall: 8860.3809,daul_VAE:8860.3545,KL:0.0167,Center:94.5271
# INFO:scDualGN.run:Epoch 23/30, Loss - overall: 8856.4694,daul_VAE:8856.4430,KL:0.0166,Center:94.0891
# INFO:scDualGN.run:Epoch 24/30, Loss - overall: 8849.4822,daul_VAE:8849.4558,KL:0.0165,Center:93.6582
# INFO:scDualGN.run:Epoch 25/30, Loss - overall: 8846.1570,daul_VAE:8846.1306,KL:0.0164,Center:93.2445
# INFO:scDualGN.run:epoch 26/30
# INFO:scDualGN.evalution:acc=0.7909, nmi=0.6889, ari=4.3634
# INFO:scDualGN.run:Epoch 26/30, Loss - overall: 8841.1910,daul_VAE:8841.1650,KL:0.0168,Center:92.8618
# INFO:scDualGN.run:Epoch 27/30, Loss - overall: 8838.3045,daul_VAE:8838.2790,KL:0.0167,Center:92.3905
# INFO:scDualGN.run:Epoch 28/30, Loss - overall: 8830.3321,daul_VAE:8830.3067,KL:0.0166,Center:92.0359
# INFO:scDualGN.run:Epoch 29/30, Loss - overall: 8827.7202,daul_VAE:8827.6948,KL:0.0166,Center:91.5506
# INFO:scDualGN.run:Epoch 30/30, Loss - overall: 8823.3218,daul_VAE:8823.2965,KL:0.0164,Center:91.1501
# INFO:scDualGN.run:scDualGN train finished.
# INFO:scDualGN.evalution:acc=0.7916, nmi=0.6868, ari=4.5247
# running time = 447.1059534549713
